# %% [markdown]
# # 在FER数据集上训练

# %% [markdown]
# ### Resnet18 - Baseline

# %%
content = '''
{
	"data_path": "data/fer2013",
	"image_size": 224,
	"in_channels": 3,
	"num_classes": 7,
	"arch": "resnet_at",
	"lr":  0.001,
    "min_lr": 0.00000001,
	"weighted_loss": 0,
	"momentum": 0.9,
	"weight_decay": 0.001,
	"distributed": 0,
	"batch_size": 48, 
	"num_workers": 8,
	"device": "cuda:0",
	"max_epoch_num": 100,
	"max_plateau_count": 8,
	"plateau_patience": 2,
	"steplr": 50,
	"log_dir": "log",
	"checkpoint_dir": "checkpoint",
	"model_name": "resnet_at",
    "model_kw": {
        "resnet_type": "resnet18", 
        "pretrained": false, 
        "drop": 0.5, 
        "filters": [64, 64, 128, 256, 512], 
        "at_type": "AG", 
        "at_layer": [0, 0, 0, 0, 0], 
        "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
	}
}
'''
with open('configs/test.json', 'w') as f:
    f.write(content)

with open('configs/test.json', 'r') as f:
    print(f.read())
# Out:
# {
# 	"data_path": "data/fer2013",
# 	"image_size": 224,
# 	"in_channels": 3,
# 	"num_classes": 7,
# 	"arch": "resnet_at",
# 	"lr":  0.001,
#     "min_lr": 0.00000001,
# 	"weighted_loss": 0,
# 	"momentum": 0.9,
# 	"weight_decay": 0.001,
# 	"distributed": 0,
# 	"batch_size": 48,
# 	"num_workers": 8,
# 	"device": "cuda:0",
# 	"max_epoch_num": 100,
# 	"max_plateau_count": 8,
# 	"plateau_patience": 2,
# 	"steplr": 50,
# 	"log_dir": "log",
# 	"checkpoint_dir": "checkpoint",
# 	"model_name": "resnet_at",
#     "model_kw": {
#         "resnet_type": "resnet18",
#         "pretrained": false,
#         "drop": 0.5,
#         "filters": [64, 64, 128, 256, 512],
#         "at_type": "AG",
#         "at_layer": [0, 0, 0, 0, 0],
#         "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
# 	}
# }

# %%
# !python main_fer2013.py --config_path configs/test.json
# Out:
# Start trainer..
# {'data_path': 'data/fer2013', 'image_size': 224, 'in_channels': 3, 'num_classes': 7, 'arch': 'resnet_at', 'lr': 0.001, 'min_lr': 1e-08, 'weighted_loss': 0, 'momentum': 0.9, 'weight_decay': 0.001, 'distributed': 0, 'batch_size': 48, 'num_workers': 8, 'device': 'cuda:0', 'max_epoch_num': 100, 'max_plateau_count': 8, 'plateau_patience': 2, 'steplr': 50, 'log_dir': 'log', 'checkpoint_dir': 'checkpoint', 'model_name': 'resnet_at', 'model_kw': {'resnet_type': 'resnet18', 'pretrained': False, 'drop': 0.5, 'filters': [64, 64, 128, 256, 512], 'at_type': 'AG', 'at_layer': [0, 0, 0, 0, 0], 'at_kws': [{'in_channels': 64, 'ratio': 1.0}, {'in_channels': 64, 'ratio': 1.0}, {'in_channels': 128, 'ratio': 1.0}, {'in_channels': 256, 'ratio': 1.0}, {'in_channels': 512, 'ratio': 1.0}]}, 'cwd': '/home/a/zss/FER'}
#   0%|                                                   | 0/599 [00:00<?, ?it/s]/home/a/zss/FER/utils/radam.py:45: UserWarning: This overload of addcmul_ is deprecated:
# ...

# %% [markdown]
# checkpoint/resnet_at_18_224

# %% [markdown]
# ### 插入AttentionGate 在Resnet的几个特征层

# %% [markdown]
# #### 在第一层加入

# %%
content = '''
{
	"data_path": "data/fer2013",
	"image_size": 224,
	"in_channels": 3,
	"num_classes": 7,
	"arch": "resnet_at",
	"lr":  0.001,
    "min_lr": 0.00000001,
	"weighted_loss": 0,
	"momentum": 0.9,
	"weight_decay": 0.001,
	"distributed": 0,
	"batch_size": 48, 
	"num_workers": 8,
	"device": "cuda:0",
	"max_epoch_num": 100,
	"max_plateau_count": 8,
	"plateau_patience": 2,
	"steplr": 50,
	"log_dir": "log",
	"checkpoint_dir": "checkpoint",
	"model_name": "resnet_at",
    "model_kw": {
        "resnet_type": "resnet18", 
        "pretrained": false, 
        "drop": 0.5, 
        "filters": [64, 64, 128, 256, 512], 
        "at_type": "AG", 
        "at_layer": [1, 0, 0, 0, 0], 
        "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
	}
}
'''
with open('configs/test.json', 'w') as f:
    f.write(content)

with open('configs/test.json', 'r') as f:
    print(f.read())
# Out:
# {
# 	"data_path": "data/fer2013",
# 	"image_size": 224,
# 	"in_channels": 3,
# 	"num_classes": 7,
# 	"arch": "resnet_at",
# 	"lr":  0.001,
#     "min_lr": 0.00000001,
# 	"weighted_loss": 0,
# 	"momentum": 0.9,
# 	"weight_decay": 0.001,
# 	"distributed": 0,
# 	"batch_size": 48,
# 	"num_workers": 8,
# 	"device": "cuda:0",
# 	"max_epoch_num": 100,
# 	"max_plateau_count": 8,
# 	"plateau_patience": 2,
# 	"steplr": 50,
# 	"log_dir": "log",
# 	"checkpoint_dir": "checkpoint",
# 	"model_name": "resnet_at",
#     "model_kw": {
#         "resnet_type": "resnet18",
#         "pretrained": false,
#         "drop": 0.5,
#         "filters": [64, 64, 128, 256, 512],
#         "at_type": "AG",
#         "at_layer": [1, 0, 0, 0, 0],
#         "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
# 	}
# }

# %%
# !python main_fer2013.py --config_path configs/test.json
# Out:
# Start trainer..
# {'data_path': 'data/fer2013', 'image_size': 224, 'in_channels': 3, 'num_classes': 7, 'arch': 'resnet_at', 'lr': 0.001, 'min_lr': 1e-08, 'weighted_loss': 0, 'momentum': 0.9, 'weight_decay': 0.001, 'distributed': 0, 'batch_size': 48, 'num_workers': 8, 'device': 'cuda:0', 'max_epoch_num': 100, 'max_plateau_count': 8, 'plateau_patience': 2, 'steplr': 50, 'log_dir': 'log', 'checkpoint_dir': 'checkpoint', 'model_name': 'resnet_at', 'model_kw': {'resnet_type': 'resnet18', 'pretrained': False, 'drop': 0.5, 'filters': [64, 64, 128, 256, 512], 'at_type': 'AG', 'at_layer': [1, 0, 0, 0, 0], 'at_kws': [{'in_channels': 64, 'ratio': 1.0}, {'in_channels': 64, 'ratio': 1.0}, {'in_channels': 128, 'ratio': 1.0}, {'in_channels': 256, 'ratio': 1.0}, {'in_channels': 512, 'ratio': 1.0}]}, 'cwd': '/home/a/zss/FER'}
#   0%|                                                   | 0/599 [00:00<?, ?it/s]/home/a/zss/FER/utils/radam.py:45: UserWarning: This overload of addcmul_ is deprecated:
# ...

# %% [markdown]
# checkpoint/resnet_at_AG_1_224

# %% [markdown]
# 2.651G 11.563M

# %% [markdown]
# #### 在第二层加入

# %%
content = '''
{
	"data_path": "data/fer2013",
	"image_size": 224,
	"in_channels": 3,
	"num_classes": 7,
	"arch": "resnet_at",
	"lr":  0.001,
    "min_lr": 0.00000001,
	"weighted_loss": 0,
	"momentum": 0.9,
	"weight_decay": 0.001,
	"distributed": 0,
	"batch_size": 48, 
	"num_workers": 8,
	"device": "cuda:0",
	"max_epoch_num": 100,
	"max_plateau_count": 8,
	"plateau_patience": 2,
	"steplr": 50,
	"log_dir": "log",
	"checkpoint_dir": "checkpoint",
	"model_name": "resnet_at",
    "model_kw": {
        "resnet_type": "resnet18", 
        "pretrained": false, 
        "drop": 0.5, 
        "filters": [64, 64, 128, 256, 512], 
        "at_type": "AG", 
        "at_layer": [0, 1, 0, 0, 0], 
        "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
	}
}
'''
with open('configs/test.json', 'w') as f:
    f.write(content)

with open('configs/test.json', 'r') as f:
    print(f.read())
# Out:
# {
# 	"data_path": "data/fer2013",
# 	"image_size": 224,
# 	"in_channels": 3,
# 	"num_classes": 7,
# 	"arch": "resnet_at",
# 	"lr":  0.001,
#     "min_lr": 0.00000001,
# 	"weighted_loss": 0,
# 	"momentum": 0.9,
# 	"weight_decay": 0.001,
# 	"distributed": 0,
# 	"batch_size": 48,
# 	"num_workers": 8,
# 	"device": "cuda:0",
# 	"max_epoch_num": 100,
# 	"max_plateau_count": 8,
# 	"plateau_patience": 2,
# 	"steplr": 50,
# 	"log_dir": "log",
# 	"checkpoint_dir": "checkpoint",
# 	"model_name": "resnet_at",
#     "model_kw": {
#         "resnet_type": "resnet18",
#         "pretrained": false,
#         "drop": 0.5,
#         "filters": [64, 64, 128, 256, 512],
#         "at_type": "AG",
#         "at_layer": [0, 1, 0, 0, 0],
#         "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
# 	}
# }

# %%
# !python main_fer2013.py --config_path configs/test.json
# Out:
# Start trainer..
# {'data_path': 'data/fer2013', 'image_size': 224, 'in_channels': 3, 'num_classes': 7, 'arch': 'resnet_at', 'lr': 0.001, 'min_lr': 1e-08, 'weighted_loss': 0, 'momentum': 0.9, 'weight_decay': 0.001, 'distributed': 0, 'batch_size': 48, 'num_workers': 8, 'device': 'cuda:0', 'max_epoch_num': 100, 'max_plateau_count': 8, 'plateau_patience': 2, 'steplr': 50, 'log_dir': 'log', 'checkpoint_dir': 'checkpoint', 'model_name': 'resnet_at', 'model_kw': {'resnet_type': 'resnet18', 'pretrained': False, 'drop': 0.5, 'filters': [64, 64, 128, 256, 512], 'at_type': 'AG', 'at_layer': [0, 1, 0, 0, 0], 'at_kws': [{'in_channels': 64, 'ratio': 1.0}, {'in_channels': 64, 'ratio': 1.0}, {'in_channels': 128, 'ratio': 1.0}, {'in_channels': 256, 'ratio': 1.0}, {'in_channels': 512, 'ratio': 1.0}]}, 'cwd': '/home/a/zss/FER'}
#   0%|                                                   | 0/599 [00:00<?, ?it/s]/home/a/zss/FER/utils/radam.py:45: UserWarning: This overload of addcmul_ is deprecated:
# ...

# %% [markdown]
# checkpoint/resnet_at_AG_2_224

# %% [markdown]
# #### 在第三层加入

# %%
content = '''
{
	"data_path": "data/fer2013",
	"image_size": 224,
	"in_channels": 3,
	"num_classes": 7,
	"arch": "resnet_at",
	"lr":  0.001,
    "min_lr": 0.00000001,
	"weighted_loss": 0,
	"momentum": 0.9,
	"weight_decay": 0.001,
	"distributed": 0,
	"batch_size": 48, 
	"num_workers": 8,
	"device": "cuda:0",
	"max_epoch_num": 100,
	"max_plateau_count": 8,
	"plateau_patience": 2,
	"steplr": 50,
	"log_dir": "log",
	"checkpoint_dir": "checkpoint",
	"model_name": "resnet_at",
    "model_kw": {
        "resnet_type": "resnet18", 
        "pretrained": false, 
        "drop": 0.5, 
        "filters": [64, 64, 128, 256, 512], 
        "at_type": "AG", 
        "at_layer": [0, 0, 1, 0, 0], 
        "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
	}
}
'''
with open('configs/test.json', 'w') as f:
    f.write(content)

with open('configs/test.json', 'r') as f:
    print(f.read())
# Out:
# {
# 	"data_path": "data/fer2013",
# 	"image_size": 224,
# 	"in_channels": 3,
# 	"num_classes": 7,
# 	"arch": "resnet_at",
# 	"lr":  0.001,
#     "min_lr": 0.00000001,
# 	"weighted_loss": 0,
# 	"momentum": 0.9,
# 	"weight_decay": 0.001,
# 	"distributed": 0,
# 	"batch_size": 48,
# 	"num_workers": 8,
# 	"device": "cuda:0",
# 	"max_epoch_num": 100,
# 	"max_plateau_count": 8,
# 	"plateau_patience": 2,
# 	"steplr": 50,
# 	"log_dir": "log",
# 	"checkpoint_dir": "checkpoint",
# 	"model_name": "resnet_at",
#     "model_kw": {
#         "resnet_type": "resnet18",
#         "pretrained": false,
#         "drop": 0.5,
#         "filters": [64, 64, 128, 256, 512],
#         "at_type": "AG",
#         "at_layer": [0, 0, 1, 0, 0],
#         "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
# 	}
# }

# %%
# !python main_fer2013.py --config_path configs/test.json
# Out:
# Start trainer..
# {'data_path': 'data/fer2013', 'image_size': 224, 'in_channels': 3, 'num_classes': 7, 'arch': 'resnet_at', 'lr': 0.001, 'min_lr': 1e-08, 'weighted_loss': 0, 'momentum': 0.9, 'weight_decay': 0.001, 'distributed': 0, 'batch_size': 48, 'num_workers': 8, 'device': 'cuda:0', 'max_epoch_num': 100, 'max_plateau_count': 8, 'plateau_patience': 2, 'steplr': 50, 'log_dir': 'log', 'checkpoint_dir': 'checkpoint', 'model_name': 'resnet_at', 'model_kw': {'resnet_type': 'resnet18', 'pretrained': False, 'drop': 0.5, 'filters': [64, 64, 128, 256, 512], 'at_type': 'AG', 'at_layer': [0, 0, 1, 0, 0], 'at_kws': [{'in_channels': 64, 'ratio': 1.0}, {'in_channels': 64, 'ratio': 1.0}, {'in_channels': 128, 'ratio': 1.0}, {'in_channels': 256, 'ratio': 1.0}, {'in_channels': 512, 'ratio': 1.0}]}, 'cwd': '/home/a/zss/FER'}
#   0%|                                                   | 0/599 [00:00<?, ?it/s]/home/a/zss/FER/utils/radam.py:45: UserWarning: This overload of addcmul_ is deprecated:
# ...

# %% [markdown]
# checkpoint/resnet_at_AG_3_224

# %% [markdown]
# #### 在第四层插入

# %%
content = '''
{
	"data_path": "data/fer2013",
	"image_size": 224,
	"in_channels": 3,
	"num_classes": 7,
	"arch": "resnet_at",
	"lr":  0.001,
    "min_lr": 0.00000001,
	"weighted_loss": 0,
	"momentum": 0.9,
	"weight_decay": 0.001,
	"distributed": 0,
	"batch_size": 48, 
	"num_workers": 8,
	"device": "cuda:0",
	"max_epoch_num": 100,
	"max_plateau_count": 8,
	"plateau_patience": 2,
	"steplr": 50,
	"log_dir": "log",
	"checkpoint_dir": "checkpoint",
	"model_name": "resnet_at",
    "model_kw": {
        "resnet_type": "resnet18", 
        "pretrained": false, 
        "drop": 0.5, 
        "filters": [64, 64, 128, 256, 512], 
        "at_type": "AG", 
        "at_layer": [0, 0, 0, 1, 0], 
        "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
	}
}
'''
with open('configs/test.json', 'w') as f:
    f.write(content)

with open('configs/test.json', 'r') as f:
    print(f.read())
# Out:
# {
# 	"data_path": "data/fer2013",
# 	"image_size": 224,
# 	"in_channels": 3,
# 	"num_classes": 7,
# 	"arch": "resnet_at",
# 	"lr":  0.001,
#     "min_lr": 0.00000001,
# 	"weighted_loss": 0,
# 	"momentum": 0.9,
# 	"weight_decay": 0.001,
# 	"distributed": 0,
# 	"batch_size": 48,
# 	"num_workers": 8,
# 	"device": "cuda:0",
# 	"max_epoch_num": 100,
# 	"max_plateau_count": 8,
# 	"plateau_patience": 2,
# 	"steplr": 50,
# 	"log_dir": "log",
# 	"checkpoint_dir": "checkpoint",
# 	"model_name": "resnet_at",
#     "model_kw": {
#         "resnet_type": "resnet18",
#         "pretrained": false,
#         "drop": 0.5,
#         "filters": [64, 64, 128, 256, 512],
#         "at_type": "AG",
#         "at_layer": [0, 0, 0, 1, 0],
#         "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
# 	}
# }

# %%
# !python main_fer2013.py --config_path configs/test.json
# Out:
# Start trainer..
# {'data_path': 'data/fer2013', 'image_size': 224, 'in_channels': 3, 'num_classes': 7, 'arch': 'resnet_at', 'lr': 0.001, 'min_lr': 1e-08, 'weighted_loss': 0, 'momentum': 0.9, 'weight_decay': 0.001, 'distributed': 0, 'batch_size': 48, 'num_workers': 8, 'device': 'cuda:0', 'max_epoch_num': 100, 'max_plateau_count': 8, 'plateau_patience': 2, 'steplr': 50, 'log_dir': 'log', 'checkpoint_dir': 'checkpoint', 'model_name': 'resnet_at', 'model_kw': {'resnet_type': 'resnet18', 'pretrained': False, 'drop': 0.5, 'filters': [64, 64, 128, 256, 512], 'at_type': 'AG', 'at_layer': [0, 0, 0, 1, 0], 'at_kws': [{'in_channels': 64, 'ratio': 1.0}, {'in_channels': 64, 'ratio': 1.0}, {'in_channels': 128, 'ratio': 1.0}, {'in_channels': 256, 'ratio': 1.0}, {'in_channels': 512, 'ratio': 1.0}]}, 'cwd': '/home/a/zss/FER'}
#   0%|                                                   | 0/599 [00:00<?, ?it/s]/home/a/zss/FER/utils/radam.py:45: UserWarning: This overload of addcmul_ is deprecated:
# ...

# %% [markdown]
# checkpoint/resnet_at_AG_4_224

# %% [markdown]
# #### 在第五层插入

# %%
content = '''
{
	"data_path": "data/fer2013",
	"image_size": 224,
	"in_channels": 3,
	"num_classes": 7,
	"arch": "resnet_at",
	"lr":  0.001,
    "min_lr": 0.00000001,
	"weighted_loss": 0,
	"momentum": 0.9,
	"weight_decay": 0.001,
	"distributed": 0,
	"batch_size": 48, 
	"num_workers": 8,
	"device": "cuda:0",
	"max_epoch_num": 100,
	"max_plateau_count": 8,
	"plateau_patience": 2,
	"steplr": 50,
	"log_dir": "log",
	"checkpoint_dir": "checkpoint",
	"model_name": "resnet_at",
    "model_kw": {
        "resnet_type": "resnet18", 
        "pretrained": false, 
        "drop": 0.5, 
        "filters": [64, 64, 128, 256, 512], 
        "at_type": "AG", 
        "at_layer": [0, 0, 0, 0, 1], 
        "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
	}
}
'''
with open('configs/test.json', 'w') as f:
    f.write(content)

with open('configs/test.json', 'r') as f:
    print(f.read())
# Out:
# {
# 	"data_path": "data/fer2013",
# 	"image_size": 224,
# 	"in_channels": 3,
# 	"num_classes": 7,
# 	"arch": "resnet_at",
# 	"lr":  0.001,
#     "min_lr": 0.00000001,
# 	"weighted_loss": 0,
# 	"momentum": 0.9,
# 	"weight_decay": 0.001,
# 	"distributed": 0,
# 	"batch_size": 48,
# 	"num_workers": 8,
# 	"device": "cuda:0",
# 	"max_epoch_num": 100,
# 	"max_plateau_count": 8,
# 	"plateau_patience": 2,
# 	"steplr": 50,
# 	"log_dir": "log",
# 	"checkpoint_dir": "checkpoint",
# 	"model_name": "resnet_at",
#     "model_kw": {
#         "resnet_type": "resnet18",
#         "pretrained": false,
#         "drop": 0.5,
#         "filters": [64, 64, 128, 256, 512],
#         "at_type": "AG",
#         "at_layer": [0, 0, 0, 0, 1],
#         "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
# 	}
# }

# %%
# !python main_fer2013.py --config_path configs/test.json
# Out:
# Start trainer..
# {'data_path': 'data/fer2013', 'image_size': 224, 'in_channels': 3, 'num_classes': 7, 'arch': 'resnet_at', 'lr': 0.001, 'min_lr': 1e-08, 'weighted_loss': 0, 'momentum': 0.9, 'weight_decay': 0.001, 'distributed': 0, 'batch_size': 48, 'num_workers': 8, 'device': 'cuda:0', 'max_epoch_num': 100, 'max_plateau_count': 8, 'plateau_patience': 2, 'steplr': 50, 'log_dir': 'log', 'checkpoint_dir': 'checkpoint', 'model_name': 'resnet_at', 'model_kw': {'resnet_type': 'resnet18', 'pretrained': False, 'drop': 0.5, 'filters': [64, 64, 128, 256, 512], 'at_type': 'AG', 'at_layer': [0, 0, 0, 0, 1], 'at_kws': [{'in_channels': 64, 'ratio': 1.0}, {'in_channels': 64, 'ratio': 1.0}, {'in_channels': 128, 'ratio': 1.0}, {'in_channels': 256, 'ratio': 1.0}, {'in_channels': 512, 'ratio': 1.0}]}, 'cwd': '/home/a/zss/FER'}
#   0%|                                                   | 0/599 [00:00<?, ?it/s]/home/a/zss/FER/utils/radam.py:45: UserWarning: This overload of addcmul_ is deprecated:
# ...

# %% [markdown]
# checkpoint/resnet_at_AG_5_224

# %% [markdown]
# ### 插入Attention_Gate2模块

# %% [markdown]
# #### 在第一层插入

# %%
content = '''
{
	"data_path": "data/fer2013",
	"image_size": 224,
	"in_channels": 3,
	"num_classes": 7,
	"arch": "resnet_at",
	"lr":  0.001,
    "min_lr": 0.00000001,
	"weighted_loss": 0,
	"momentum": 0.9,
	"weight_decay": 0.001,
	"distributed": 0,
	"batch_size": 48, 
	"num_workers": 8,
	"device": "cuda:0",
	"max_epoch_num": 100,
	"max_plateau_count": 8,
	"plateau_patience": 2,
	"steplr": 50,
	"log_dir": "log",
	"checkpoint_dir": "checkpoint",
	"model_name": "resnet_at",
    "model_kw": {
        "resnet_type": "resnet18", 
        "pretrained": false, 
        "drop": 0.5, 
        "filters": [64, 64, 128, 256, 512], 
        "at_type": "AG2", 
        "at_layer": [1, 0, 0, 0, 0], 
        "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
	}
}
'''
with open('configs/test.json', 'w') as f:
    f.write(content)

with open('configs/test.json', 'r') as f:
    print(f.read())
# Out:
# {
# 	"data_path": "data/fer2013",
# 	"image_size": 224,
# 	"in_channels": 3,
# 	"num_classes": 7,
# 	"arch": "resnet_at",
# 	"lr":  0.001,
#     "min_lr": 0.00000001,
# 	"weighted_loss": 0,
# 	"momentum": 0.9,
# 	"weight_decay": 0.001,
# 	"distributed": 0,
# 	"batch_size": 48,
# 	"num_workers": 8,
# 	"device": "cuda:0",
# 	"max_epoch_num": 100,
# 	"max_plateau_count": 8,
# 	"plateau_patience": 2,
# 	"steplr": 50,
# 	"log_dir": "log",
# 	"checkpoint_dir": "checkpoint",
# 	"model_name": "resnet_at",
#     "model_kw": {
#         "resnet_type": "resnet18",
#         "pretrained": false,
#         "drop": 0.5,
#         "filters": [64, 64, 128, 256, 512],
#         "at_type": "AG2",
#         "at_layer": [1, 0, 0, 0, 0],
#         "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
# 	}
# }

# %%
# !python main_fer2013.py --config_path configs/test.json
# Out:
# Start trainer..
# {'data_path': 'data/fer2013', 'image_size': 224, 'in_channels': 3, 'num_classes': 7, 'arch': 'resnet_at', 'lr': 0.001, 'min_lr': 1e-08, 'weighted_loss': 0, 'momentum': 0.9, 'weight_decay': 0.001, 'distributed': 0, 'batch_size': 48, 'num_workers': 8, 'device': 'cuda:0', 'max_epoch_num': 100, 'max_plateau_count': 8, 'plateau_patience': 2, 'steplr': 50, 'log_dir': 'log', 'checkpoint_dir': 'checkpoint', 'model_name': 'resnet_at', 'model_kw': {'resnet_type': 'resnet18', 'pretrained': False, 'drop': 0.5, 'filters': [64, 64, 128, 256, 512], 'at_type': 'AG2', 'at_layer': [1, 0, 0, 0, 0], 'at_kws': [{'in_channels': 64, 'ratio': 1.0}, {'in_channels': 64, 'ratio': 1.0}, {'in_channels': 128, 'ratio': 1.0}, {'in_channels': 256, 'ratio': 1.0}, {'in_channels': 512, 'ratio': 1.0}]}, 'cwd': '/home/a/zss/FER'}
#   0%|                                                   | 0/599 [00:00<?, ?it/s]/home/a/zss/FER/utils/radam.py:45: UserWarning: This overload of addcmul_ is deprecated:
# ...

# %% [markdown]
# #### 在第二层插入

# %%
content = '''
{
	"data_path": "data/fer2013",
	"image_size": 224,
	"in_channels": 3,
	"num_classes": 7,
	"arch": "resnet_at",
	"lr":  0.001,
    "min_lr": 0.00000001,
	"weighted_loss": 0,
	"momentum": 0.9,
	"weight_decay": 0.001,
	"distributed": 0,
	"batch_size": 48, 
	"num_workers": 8,
	"device": "cuda:0",
	"max_epoch_num": 100,
	"max_plateau_count": 8,
	"plateau_patience": 2,
	"steplr": 50,
	"log_dir": "log",
	"checkpoint_dir": "checkpoint",
	"model_name": "resnet_at",
    "model_kw": {
        "resnet_type": "resnet18", 
        "pretrained": false, 
        "drop": 0.5, 
        "filters": [64, 64, 128, 256, 512], 
        "at_type": "AG2", 
        "at_layer": [0, 1, 0, 0, 0], 
        "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
	}
}
'''
with open('configs/test.json', 'w') as f:
    f.write(content)

with open('configs/test.json', 'r') as f:
    print(f.read())
# Out:
# {
# 	"data_path": "data/fer2013",
# 	"image_size": 224,
# 	"in_channels": 3,
# 	"num_classes": 7,
# 	"arch": "resnet_at",
# 	"lr":  0.001,
#     "min_lr": 0.00000001,
# 	"weighted_loss": 0,
# 	"momentum": 0.9,
# 	"weight_decay": 0.001,
# 	"distributed": 0,
# 	"batch_size": 48,
# 	"num_workers": 8,
# 	"device": "cuda:0",
# 	"max_epoch_num": 100,
# 	"max_plateau_count": 8,
# 	"plateau_patience": 2,
# 	"steplr": 50,
# 	"log_dir": "log",
# 	"checkpoint_dir": "checkpoint",
# 	"model_name": "resnet_at",
#     "model_kw": {
#         "resnet_type": "resnet18",
#         "pretrained": false,
#         "drop": 0.5,
#         "filters": [64, 64, 128, 256, 512],
#         "at_type": "AG2",
#         "at_layer": [0, 1, 0, 0, 0],
#         "at_kws": [{"in_channels": 64, "ratio": 1.0}, {"in_channels": 64, "ratio": 1.0}, {"in_channels": 128, "ratio": 1.0}, {"in_channels": 256, "ratio": 1.0}, {"in_channels": 512, "ratio": 1.0}]
# 	}
# }

# %%
# !python main_fer2013.py --config_path configs/test.json
# Out:
# Start trainer..
# {'data_path': 'data/fer2013', 'image_size': 224, 'in_channels': 3, 'num_classes': 7, 'arch': 'resnet_at', 'lr': 0.001, 'min_lr': 1e-08, 'weighted_loss': 0, 'momentum': 0.9, 'weight_decay': 0.001, 'distributed': 0, 'batch_size': 48, 'num_workers': 8, 'device': 'cuda:0', 'max_epoch_num': 100, 'max_plateau_count': 8, 'plateau_patience': 2, 'steplr': 50, 'log_dir': 'log', 'checkpoint_dir': 'checkpoint', 'model_name': 'resnet_at', 'model_kw': {'resnet_type': 'resnet18', 'pretrained': False, 'drop': 0.5, 'filters': [64, 64, 128, 256, 512], 'at_type': 'AG2', 'at_layer': [0, 1, 0, 0, 0], 'at_kws': [{'in_channels': 64, 'ratio': 1.0}, {'in_channels': 64, 'ratio': 1.0}, {'in_channels': 128, 'ratio': 1.0}, {'in_channels': 256, 'ratio': 1.0}, {'in_channels': 512, 'ratio': 1.0}]}, 'cwd': '/home/a/zss/FER'}
#   0%|                                                   | 0/599 [00:00<?, ?it/s]/home/a/zss/FER/utils/radam.py:45: UserWarning: This overload of addcmul_ is deprecated:
# ...

# %% [markdown]
# ### 插入CB模块

# %% [markdown]
# #### 在第一层插入

# %%
content = '''
{
	"data_path": "data/fer2013",
	"image_size": 224,
	"in_channels": 3,
	"num_classes": 7,
	"arch": "resnet_at",
	"lr":  0.001,
    "min_lr": 0.00000001,
	"weighted_loss": 0,
	"momentum": 0.9,
	"weight_decay": 0.001,
	"distributed": 0,
	"batch_size": 48, 
	"num_workers": 8,
	"device": "cuda:0",
	"max_epoch_num": 100,
	"max_plateau_count": 8,
	"plateau_patience": 2,
	"steplr": 50,
	"log_dir": "log",
	"checkpoint_dir": "checkpoint",
	"model_name": "resnet_CB",
    "model_kw": {
        "resnet_type": "resnet18", 
        "pretrained": false, 
        "drop": 0.5, 
        "filters": [64, 64, 128, 256, 512], 
        "at_type": "CB", 
        "at_layer": [1, 0, 0, 0, 0], 
        "at_kws": [{"inplanes": 64, "ratio": 0.25}, {"inplanes": 128, "ratio": 0.25}, {"inplanes": 256, "ratio": 0.25}, {"inplanes": 512, "ratio": 0.25}, {"inplanes": 1024, "ratio": 0.25}]
	}
}
'''
with open('configs/test.json', 'w') as f:
    f.write(content)

with open('configs/test.json', 'r') as f:
    print(f.read())
# Out:
# {
# 	"data_path": "data/fer2013",
# 	"image_size": 224,
# 	"in_channels": 3,
# 	"num_classes": 7,
# 	"arch": "resnet_at",
# 	"lr":  0.001,
#     "min_lr": 0.00000001,
# 	"weighted_loss": 0,
# 	"momentum": 0.9,
# 	"weight_decay": 0.001,
# 	"distributed": 0,
# 	"batch_size": 48,
# 	"num_workers": 8,
# 	"device": "cuda:0",
# 	"max_epoch_num": 100,
# 	"max_plateau_count": 8,
# 	"plateau_patience": 2,
# 	"steplr": 50,
# 	"log_dir": "log",
# 	"checkpoint_dir": "checkpoint",
# 	"model_name": "resnet_CB",
#     "model_kw": {
#         "resnet_type": "resnet18",
#         "pretrained": false,
#         "drop": 0.5,
#         "filters": [64, 64, 128, 256, 512],
#         "at_type": "CB",
#         "at_layer": [1, 0, 0, 0, 0],
#         "at_kws": [{"inplanes": 64, "ratio": 0.25}, {"inplanes": 128, "ratio": 0.25}, {"inplanes": 256, "ratio": 0.25}, {"inplanes": 512, "ratio": 0.25}, {"inplanes": 1024, "ratio": 0.25}]
# 	}
# }

# %%
# !python main_fer2013.py --config_path configs/test.json
# Out:
# Start trainer..
# {'data_path': 'data/fer2013', 'image_size': 224, 'in_channels': 3, 'num_classes': 7, 'arch': 'resnet_at', 'lr': 0.001, 'min_lr': 1e-08, 'weighted_loss': 0, 'momentum': 0.9, 'weight_decay': 0.001, 'distributed': 0, 'batch_size': 48, 'num_workers': 8, 'device': 'cuda:0', 'max_epoch_num': 100, 'max_plateau_count': 8, 'plateau_patience': 2, 'steplr': 50, 'log_dir': 'log', 'checkpoint_dir': 'checkpoint', 'model_name': 'resnet_CB', 'model_kw': {'resnet_type': 'resnet18', 'pretrained': False, 'drop': 0.5, 'filters': [64, 64, 128, 256, 512], 'at_type': 'CB', 'at_layer': [1, 0, 0, 0, 0], 'at_kws': [{'inplanes': 64, 'ratio': 0.25}, {'inplanes': 128, 'ratio': 0.25}, {'inplanes': 256, 'ratio': 0.25}, {'inplanes': 512, 'ratio': 0.25}, {'inplanes': 1024, 'ratio': 0.25}]}, 'cwd': '/home/a/zss/FER'}
#   0%|                                                   | 0/599 [00:00<?, ?it/s]/home/a/zss/FER/utils/radam.py:45: UserWarning: This overload of addcmul_ is deprecated:
# ...

# %% [markdown]
# checkpoint/resnet_at_CB_1_224

# %% [markdown]
# #### 在第二层插入

# %%
content = '''
{
	"data_path": "data/fer2013",
	"image_size": 224,
	"in_channels": 3,
	"num_classes": 7,
	"arch": "resnet_at",
	"lr":  0.001,
    "min_lr": 0.00000001,
	"weighted_loss": 0,
	"momentum": 0.9,
	"weight_decay": 0.001,
	"distributed": 0,
	"batch_size": 48, 
	"num_workers": 8,
	"device": "cuda:0",
	"max_epoch_num": 100,
	"max_plateau_count": 8,
	"plateau_patience": 2,
	"steplr": 50,
	"log_dir": "log",
	"checkpoint_dir": "checkpoint",
	"model_name": "resnet_CB",
    "model_kw": {
        "resnet_type": "resnet18", 
        "pretrained": false, 
        "drop": 0.5, 
        "filters": [64, 64, 128, 256, 512], 
        "at_type": "CB", 
        "at_layer": [0, 1, 0, 0, 0], 
        "at_kws": [{"inplanes": 64, "ratio": 0.25}, {"inplanes": 64, "ratio": 0.25}, {"inplanes": 256, "ratio": 0.25}, {"inplanes": 512, "ratio": 0.25}, {"inplanes": 1024, "ratio": 0.25}]
	}
}
'''
with open('configs/test.json', 'w') as f:
    f.write(content)

with open('configs/test.json', 'r') as f:
    print(f.read())
# Out:
# {
# 	"data_path": "data/fer2013",
# 	"image_size": 224,
# 	"in_channels": 3,
# 	"num_classes": 7,
# 	"arch": "resnet_at",
# 	"lr":  0.001,
#     "min_lr": 0.00000001,
# 	"weighted_loss": 0,
# 	"momentum": 0.9,
# 	"weight_decay": 0.001,
# 	"distributed": 0,
# 	"batch_size": 48,
# 	"num_workers": 8,
# 	"device": "cuda:0",
# 	"max_epoch_num": 100,
# 	"max_plateau_count": 8,
# 	"plateau_patience": 2,
# 	"steplr": 50,
# 	"log_dir": "log",
# 	"checkpoint_dir": "checkpoint",
# 	"model_name": "resnet_CB",
#     "model_kw": {
#         "resnet_type": "resnet18",
#         "pretrained": false,
#         "drop": 0.5,
#         "filters": [64, 64, 128, 256, 512],
#         "at_type": "CB",
#         "at_layer": [0, 1, 0, 0, 0],
#         "at_kws": [{"inplanes": 64, "ratio": 0.25}, {"inplanes": 64, "ratio": 0.25}, {"inplanes": 256, "ratio": 0.25}, {"inplanes": 512, "ratio": 0.25}, {"inplanes": 1024, "ratio": 0.25}]
# 	}
# }

# %%
# !python main_fer2013.py --config_path configs/test.json
# Out:
# Start trainer..
# {'data_path': 'data/fer2013', 'image_size': 224, 'in_channels': 3, 'num_classes': 7, 'arch': 'resnet_at', 'lr': 0.001, 'min_lr': 1e-08, 'weighted_loss': 0, 'momentum': 0.9, 'weight_decay': 0.001, 'distributed': 0, 'batch_size': 48, 'num_workers': 8, 'device': 'cuda:0', 'max_epoch_num': 100, 'max_plateau_count': 8, 'plateau_patience': 2, 'steplr': 50, 'log_dir': 'log', 'checkpoint_dir': 'checkpoint', 'model_name': 'resnet_CB', 'model_kw': {'resnet_type': 'resnet18', 'pretrained': False, 'drop': 0.5, 'filters': [64, 64, 128, 256, 512], 'at_type': 'CB', 'at_layer': [0, 1, 0, 0, 0], 'at_kws': [{'inplanes': 64, 'ratio': 0.25}, {'inplanes': 64, 'ratio': 0.25}, {'inplanes': 256, 'ratio': 0.25}, {'inplanes': 512, 'ratio': 0.25}, {'inplanes': 1024, 'ratio': 0.25}]}, 'cwd': '/home/a/zss/FER'}
#   0%|                                                   | 0/599 [00:00<?, ?it/s]/home/a/zss/FER/utils/radam.py:45: UserWarning: This overload of addcmul_ is deprecated:
# ...

# %% [markdown]
# checkpoint/resnet_at_CB_2_224

# %% [markdown]
# ### 插入PSA模块

# %% [markdown]
# #### 在第一层插入

# %%
content = '''
{
	"data_path": "data/fer2013",
	"image_size": 224,
	"in_channels": 3,
	"num_classes": 7,
	"arch": "resnet_at",
	"lr":  0.001,
    "min_lr": 0.00000001,
	"weighted_loss": 0,
	"momentum": 0.9,
	"weight_decay": 0.001,
	"distributed": 0,
	"batch_size": 48, 
	"num_workers": 8,
	"device": "cuda:0",
	"max_epoch_num": 100,
	"max_plateau_count": 8,
	"plateau_patience": 2,
	"steplr": 50,
	"log_dir": "log",
	"checkpoint_dir": "checkpoint",
	"model_name": "resnet_CB",
    "model_kw": {
        "resnet_type": "resnet18", 
        "pretrained": false, 
        "drop": 0.5, 
        "filters": [64, 64, 128, 256, 512], 
        "at_type": "PSA", 
        "at_layer": [1, 0, 0, 0, 0], 
        "at_kws": [{"inplans": 64, "planes": 64, "conv_kernels": [3, 5, 7, 9], "stride": 1, "conv_groups": [1, 4, 8, 16]}, {"inplans": 64, "planes": 64, "conv_kernels": [3, 5, 7, 9], "stride": 1, "conv_groups": [1, 4, 8, 16]}, {"inplans": 128, "planes": 128, "conv_kernels": [3, 5, 7, 9], "stride": 1, "conv_groups": [1, 4, 8, 16]}, {"inplans": 256, "planes": 256, "conv_kernels": [3, 5, 7, 9], "stride": 1, "conv_groups": [1, 4, 8, 16]}, {"inplans": 512, "planes": 512, "conv_kernels": [3, 5, 7, 9], "stride": 1, "conv_groups": [1, 4, 8, 16]}]
	}
}
'''
with open('configs/test.json', 'w') as f:
    f.write(content)

with open('configs/test.json', 'r') as f:
    print(f.read())
# Out:
# {
# 	"data_path": "data/fer2013",
# 	"image_size": 224,
# 	"in_channels": 3,
# 	"num_classes": 7,
# 	"arch": "resnet_at",
# 	"lr":  0.001,
#     "min_lr": 0.00000001,
# 	"weighted_loss": 0,
# 	"momentum": 0.9,
# 	"weight_decay": 0.001,
# 	"distributed": 0,
# 	"batch_size": 48,
# 	"num_workers": 8,
# 	"device": "cuda:0",
# 	"max_epoch_num": 100,
# 	"max_plateau_count": 8,
# 	"plateau_patience": 2,
# 	"steplr": 50,
# 	"log_dir": "log",
# 	"checkpoint_dir": "checkpoint",
# 	"model_name": "resnet_CB",
#     "model_kw": {
#         "resnet_type": "resnet18",
#         "pretrained": false,
#         "drop": 0.5,
#         "filters": [64, 64, 128, 256, 512],
#         "at_type": "PSA",
#         "at_layer": [1, 0, 0, 0, 0],
# ...

# %%
# !python main_fer2013.py --config_path configs/test.json
# Out:
# Start trainer..
# ...

# %% [markdown]
# checkpoint/resnet_at_PSA_1_224

# %% [markdown]
# #### 在第二层插入

# %%
content = '''
{
	"data_path": "data/fer2013",
	"image_size": 224,
	"in_channels": 3,
	"num_classes": 7,
	"arch": "resnet_at",
	"lr":  0.001,
    "min_lr": 0.00000001,
	"weighted_loss": 0,
	"momentum": 0.9,
	"weight_decay": 0.001,
	"distributed": 0,
	"batch_size": 48, 
	"num_workers": 8,
	"device": "cuda:0",
	"max_epoch_num": 100,
	"max_plateau_count": 8,
	"plateau_patience": 2,
	"steplr": 50,
	"log_dir": "log",
	"checkpoint_dir": "checkpoint",
	"model_name": "resnet_CB",
    "model_kw": {
        "resnet_type": "resnet18", 
        "pretrained": false, 
        "drop": 0.5, 
        "filters": [64, 64, 128, 256, 512], 
        "at_type": "PSA", 
        "at_layer": [0, 1, 0, 0, 0], 
        "at_kws": [{"inplans": 64, "planes": 64, "conv_kernels": [3, 5, 7, 9], "stride": 1, "conv_groups": [1, 4, 8, 16]}, {"inplans": 64, "planes": 64, "conv_kernels": [3, 5, 7, 9], "stride": 1, "conv_groups": [1, 4, 8, 16]}, {"inplans": 128, "planes": 128, "conv_kernels": [3, 5, 7, 9], "stride": 1, "conv_groups": [1, 4, 8, 16]}, {"inplans": 256, "planes": 256, "conv_kernels": [3, 5, 7, 9], "stride": 1, "conv_groups": [1, 4, 8, 16]}, {"inplans": 512, "planes": 512, "conv_kernels": [3, 5, 7, 9], "stride": 1, "conv_groups": [1, 4, 8, 16]}]
	}
}
'''
with open('configs/test.json', 'w') as f:
    f.write(content)

with open('configs/test.json', 'r') as f:
    print(f.read())
# Out:
# {
# 	"data_path": "data/fer2013",
# 	"image_size": 224,
# 	"in_channels": 3,
# 	"num_classes": 7,
# 	"arch": "resnet_at",
# 	"lr":  0.001,
#     "min_lr": 0.00000001,
# 	"weighted_loss": 0,
# 	"momentum": 0.9,
# 	"weight_decay": 0.001,
# 	"distributed": 0,
# 	"batch_size": 48,
# 	"num_workers": 8,
# 	"device": "cuda:0",
# 	"max_epoch_num": 100,
# 	"max_plateau_count": 8,
# 	"plateau_patience": 2,
# 	"steplr": 50,
# 	"log_dir": "log",
# 	"checkpoint_dir": "checkpoint",
# 	"model_name": "resnet_CB",
#     "model_kw": {
#         "resnet_type": "resnet18",
#         "pretrained": false,
#         "drop": 0.5,
#         "filters": [64, 64, 128, 256, 512],
#         "at_type": "PSA",
#         "at_layer": [0, 1, 0, 0, 0],
# ...

# %%
# !python main_fer2013.py --config_path configs/test.json
# Out:
# Start trainer..
# ...

# %% [markdown]
# checkpoint/resnet_at_PSA_2_224
